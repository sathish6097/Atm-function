# %%
import random
class Atm:
    def __init__(self):
        self.aT_fun=[]
    def pin(self):
        while True:
            database={1231:26782548,1325:257245327,2653:235685437,1266:2635347543,1623:2738386283,1234:52374763}
            pin=int(input("Enter the pin:"))
            if pin in database.keys():
                database.get(pin)
                break
            else:
                print("~~~~~~~~~~~~~Invalid pin~~~~~~~~")
                new_=input("Are you Generate the new pin:(yes/no)")
                if new_=="yes":
                    ac_no=int(input("enter the account no:"))
                    new=int (input("enter the new pin:"))
                    database[new]=ac_no
                    pin=int(input("Enter the pin:"))
                    if pin in database.keys():
                        database.get(pin)
                        print("Thank for your conformation!!!!!")
                        break
        self.balance=random.randint(1000,100000)
        while True:
            print("\n 1.Balance!")
            print("\n 2.withdraw")
            print("\n 3.deposite")
            print("\n 4.exit")
            choice=int (input("Enter your choice!"))
            if choice==1:
                print(f"Your balance is :'{self.balance}'")
            if choice==2:
                amount=int(input("Enter the withdraw amount:"))
                if amount<=self.balance:
                    self.balance -= amount
                    print(f"Your available balance is'{self.balance}'")
                else:
                    print("Insufficient balance!!")
            elif choice==3:
                print("Only deposite 100 200 500!!")
                deposite=int(input("Enter the amount:"))
                self.balance += deposite
                print("Deposit successful.")
                print(f"your available amount is'{self.balance}'")
            elif choice==4:
                print("Thank you!!!!!!!")
                
                break
def main():
    a=Atm()
    print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
    print("\n\t\tWelcomes to Sk Atm!!")
    print("\n\t\t\t Please insert your card!!")
    print("\n pin Generate!!")
    print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
    while True:
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        print("1.Enter your pin:")
        print("2.exit")
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        choice=int(input("ennter your choice:"))
        if choice==1:
            a.pin()
        if choice==2:
            print("Have a great day!!!")
            print("you are exit!!!!")
            break
if __name__=="__main__":
    main()
# Out:
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
# 		Welcomes to Sk Atm!!
#
# 			 Please insert your card!!
#
#  pin Generate!!
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1.Enter your pin:
# 2.exit
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ennter your choice:1
# Enter the pin:1234
#
#  1.Balance!
#
#  2.withdraw
#
#  3.deposite
#
#  4.exit
# Enter your choice!1
# Your balance is :'99473'
#
#  1.Balance!
#
#  2.withdraw
#
#  3.deposite
#
#  4.exit
# Enter your choice!2
# Enter the withdraw amount:40000
# Your available balance is'59473'
#
#  1.Balance!
#
#  2.withdraw
#
#  3.deposite
#
#  4.exit
# Enter your choice!1
# Your balance is :'59473'
#
#  1.Balance!
#
#  2.withdraw
#
#  3.deposite
#
#  4.exit
# Enter your choice!2
# Enter the withdraw amount:50000
# Your available balance is'9473'
#
#  1.Balance!
#
#  2.withdraw
#
#  3.deposite
#
#  4.exit
# ...
